# %% [markdown]
# # Diabetes project

# %% [markdown]
# Pima Indians Diabetes Database Descriptive Statistics Project
# Predict the onset of diabetes based on diagnostic measures. This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether a patient has diabetes, based on certain diagnostic measurements included in the dataset.
#
#
# Columns of the dataset
# Pregnancies: Number of times pregnant
# Glucose: Plasma glucose concentration 2 hours in an oral glucose tolerance test
# Blood Pressure: Diastolic blood pressure (mm Hg)
# Skin Thickness: Triceps skin fold thickness (mm
# Insulin: 2-Hour serum insulin (mu U/ml)
# BMI: Body mass index (weight in kg/(height in m)^2)
# Diabetes Pedigree Function: Diabetes pedigree function
# Age: Age (years)
# Outcome: Class variable (0 or 1) 0 mean non-diabetic and 1 means diabetic
#
# Please do the basic exploration of data and explain missing values, number of rows and columns and data types in statistical term.
# Calculate appropriate measures of central tendency for Glucose and outcome column only?
# Please provide 5 points data summaries for required columns?
# Please create an appropriate plot to examine the relationship between Age and Glucose.
# Please create an appropriate plot to see the distribution of Outcome variable?
# Please examine the distribution of numerical data and explain which variable normally distributed and which variable is seems to be skewed. Please also tell the direction of skewness.
# Please calculate the skewness value and divide variables into symmetrical, moderately skewed and highly skewed.
# Please create appropriate plot to examine the outliers of these variables. Please name the variables which have outliers.
# What should be the measures of central tendency and dispersion for skewed data?
# Please push the assignment into your github account and provide the link of github account.

# %% [markdown]
# **Table : Description of the variables in pima diabetes dataset**
#
# |Variable | Explanation of variables |
# |:----------|:---------|
# |**Pregnancies**|Numerical discrete Number of times pregnant|
# |**Glucose**    | Nuerical continuous Plasma glucose concentration 2 hour in an oral glucose tolerance test Blood|
# |**Blood pressure**| Numerical continuous Diastolic BP in (mm Hg)|
# |**Skin Thickness**| Numerical continuous Triceps skin fold thickness (mm)|
# |**Insulin** |Numerical continuous 2-Hour serum insulin (mu U/ml)|
# |**BMI**| Numerical continuous Body mass index (weight in kg/(height in m)^2)|
# |**Diabetes Pedigree Function**| Diabetes pedigree function|
# |**Age**|Numerical continuousAge (years)|
# |**Outcome**| Categorical Nominal whether the female is diabetic or not|

# %%
import pandas as pd
import numpy as np
import matplotlib 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("diabetes (1).csv")

# %%
diabetes = pd.read_csv("pima-indians-diabetes (1) - pima-indians-diabetes (1).csv", names = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"])

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# There are 768 rows and 8 columns in this dataset.

# %%
data.isna().sum()    #isna function is showing no null values but is it true?
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# __1). The minimum vlaue for Insulin and Skinthickness as zero__
#
#
# __2). Maximum value 17 for pregnancies so we should remove this outlier as this value doesn't seem to be true.__

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
data['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
data['BloodPressure'].unique()
# Out:
# array([ 72,  66,  64,  40,  74,  50,   0,  70,  96,  92,  80,  60,  84,
#         30,  88,  90,  94,  76,  82,  75,  58,  78,  68, 110,  56,  62,
#         85,  86,  48,  44,  65, 108,  55, 122,  54,  52,  98, 104,  95,
#         46, 102, 100,  61,  24,  38, 106, 114], dtype=int64)

# %% [markdown]
# Glucose value cannot be zero but in the above array

# %%
data.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
data.describe(include = 'all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # Dealing with missing values

# %%
data['BMI'] = data['BMI'].apply(lambda x: np.nan if x == 0 else x)
data['Glucose'] = data['Glucose'].apply(lambda x: np.nan if x == 0 else x)
data['SkinThickness'] = data['SkinThickness'].apply(lambda x: np.nan if x == 0 else x)
data['BloodPressure'] = data['BloodPressure'].apply(lambda x: np.nan if x == 0 else x)
data['Insulin'] = data['Insulin'].apply(lambda x: np.nan if x == 0 else x)

# %%
import missingno as msno

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(data)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
sort = data.sort_values('SkinThickness')
msno.matrix(sort)
# Out:
# <AxesSubplot:>

# %%
sor = data.sort_values('Insulin')
msno.matrix(sor)
# Out:
# <AxesSubplot:>

# %%
so = data.sort_values('BMI')
msno.matrix(so)
# Out:
# <AxesSubplot:>

# %%
for column in data:
    plt.figure(figsize = (16,4))
    plt.subplot(1,2,1)
    plt.hist(data[column], alpha = 0.5)
    
    #Boxplot
    plt.figure(figsize = (16,4))
    plt.subplot(1,2,1)
    sns.boxplot(data[column])
    plt.show()
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# __The numerical variables with outliers are:__
#
# - SkinThickness
#
# - BloodPressure
#
# - BMI

# %%
#The numerical variables which are skewed
a = data.skew()
pd.DataFrame(a).sort_values(by = 0, ascending = False)
# Out:
#                                  0
# Insulin                   2.166464
# DiabetesPedigreeFunction  1.919911
# Age                       1.129597
# Pregnancies               0.901674
# SkinThickness             0.690619
# Outcome                   0.635017
# BMI                       0.593970
# Glucose                   0.530989
# BloodPressure             0.134153

# %% [markdown]
# __Skewed data__ :
#
#
# - DiabetesPedigreeFunction(Highly skewed)
#
# - Age(Highly skewed)
#
# - Pregnancies(Highly skewed)
#
# - SkinThickness(Moderately skewed)
#
# - Outcome(Moderately skewed)
#
# - BMI (Moderately skewed)
#
# - Glucose(Normal)
#
# - BloodPressure(normal)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # SkinThickness

# %%
sns.distplot(data.SkinThickness)
plt.axvline(x = data.SkinThickness.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.SkinThickness.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - __Treating Misiing values__

# %%
data['SkinThickness'].fillna(data['SkinThickness'].mean(),inplace = True)

# %%
data['SkinThickness'].skew()
# Out:
# 0.8221731383793047

# %% [markdown]
# __Since the distribution of Skin thickness is not normal so we first have to Normalize it.__

# %%
data['SkinThickness_sqrt'] = np.sqrt(data['SkinThickness'])
sns.distplot(data.SkinThickness_sqrt)
plt.axvline(x = data.SkinThickness_sqrt.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.SkinThickness_sqrt.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['SkinThickness_sqrt'].skew()
# Out:
# -0.15338040395085262

# %% [markdown]
# __Now the distribution of Skin Thickness is falling between -0.5 and 0.5 (as it is -0.1) so we can consider it as normally
# Distributed one.__

# %%
data['SkinThickness_sqrt'].isna().sum()    #Checking for missing values. No missing values so far.
# Out:
# 0

# %% [markdown]
# # Checking for Outliers

# %% [markdown]
# - First we will go with the IQR method to remove outliers.
#   Basically in this step we will check different quantile ranges and will look for the boundries(value upto which maximum
#   observations are present), so that we can consider the values outside the boundry as outlier.

# %%
def check_boundry(df, var):
    Q1 = np.quantile(df[var], 0.25, interpolation = 'midpoint')
    Q3 = np.quantile(df[var], 0.75, interpolation = 'midpoint')
    IQR = Q3-Q1
    lower = Q1 - 3*IQR
    upper = Q3 + 3*IQR
    return lower,upper

# %%
check_boundry(data,'SkinThickness_sqrt')
# Out:
# (3.0294372515228583, 7.627416997969522)

# %%
check_boundry(data,'BloodPressure')
# Out:
# (nan, nan)

# %%
check_boundry(data,'BMI')
# Out:
# (nan, nan)

# %%
data['SkinThickness'].isna().sum()
# Out:
# 0

# %% [markdown]
# - __Now we have upper and lower limits for each feature containing outliers so we can remove them.__

# %% [markdown]
# #  Trimming/Removing outliers

# %%
sns.boxplot(data.SkinThickness_sqrt)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SkinThickness_sqrt'>

# %%
sns.boxplot(data.SkinThickness)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SkinThickness'>

# %%
Q1 = np.quantile(data['SkinThickness'], 0.25, interpolation = 'midpoint')
Q3 = np.quantile(data['SkinThickness'], 0.75, interpolation = 'midpoint')
IQR = Q3-Q1
l = Q1 - 3*IQR     #Looking for extreme outliers
u = Q3 + 3*IQR

# %%
data[(data['SkinThickness']>u)|(data['SkinThickness']<l)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 57             0    100.0           88.0           60.0    110.0  46.8
# 86            13    106.0           72.0           54.0      NaN  36.6
# 120            0    162.0           76.0           56.0    100.0  53.2
# 211            0    147.0           85.0           54.0      NaN  42.8
# 445            0    180.0           78.0           63.0     14.0  59.4
# 579            2    197.0           70.0           99.0      NaN  34.7
#
#      DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt
# 57                      0.962   31        0            7.745967
# 86                      0.178   45        0            7.348469
# 120                     0.759   25        1            7.483315
# 211                     0.375   24        0            7.348469
# 445                     2.420   25        1            7.937254
# 579                     0.575   62        1            9.949874

# %% [markdown]
# - Six outliers have been deducted: But it won't be wise to remove them all so i will cap them with the upper limit and lower limit.

# %%
data['SkinThickness'] = np.where(data['SkinThickness']>u, u, np.where(data['SkinThickness']<l, l, data['SkinThickness']))

# %%
sns.boxplot(data.SkinThickness)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SkinThickness'>

# %%
#checking for outliers again
data[(data['SkinThickness']>u)|(data['SkinThickness']<l)]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome, SkinThickness_sqrt]
# Index: []

# %%
data['SkinThickness_log'] = np.log(data['SkinThickness'])
sns.distplot(data.SkinThickness_sqrt)
plt.axvline(x = data.SkinThickness_sqrt.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.SkinThickness_sqrt.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['SkinThickness'].skew()
# Out:
# 0.14269621247343667

# %%
data.drop(columns= 'SkinThickness_log')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0       35.00000      NaN  33.6
# 1              1     85.0           66.0       29.00000      NaN  26.6
# 2              8    183.0           64.0       29.15342      NaN  23.3
# 3              1     89.0           66.0       23.00000     94.0  28.1
# 4              0    137.0           40.0       35.00000    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0       48.00000    180.0  32.9
# 764            2    122.0           70.0       27.00000      NaN  36.8
# 765            5    121.0           72.0       23.00000    112.0  26.2
# 766            1    126.0           60.0       29.15342      NaN  30.1
# 767            1     93.0           70.0       31.00000      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt
# ...

# %% [markdown]
# - Outlier treatment and transformation done for Skinthickness.
#
#
# __Now on comparing the two scenerios in which we transformed first and then treated outlier and the one in which
# we first treated the outlier and then transformed the feature I found that the data which is transformed first is more normal as compared to the one transformed after treating outliers so we will kept that sqrt feature and will remove the log transformed feature__.

# %%
#So now we don't have any missing value for this feature(SkinThickness)

data['SkinThickness'].describe()
# Out:
# count    768.000000
# mean      29.064878
# std        8.371205
# min        7.000000
# 25%       25.000000
# 50%       29.153420
# 75%       32.000000
# max       53.000000
# Name: SkinThickness, dtype: float64

# %% [markdown]
# __The same approach we can use for other features as well and then based on their distribution we can replace their values.__

# %% [markdown]
# # Glucose

# %%
sns.distplot(data.Glucose)
plt.axvline(x = data.Glucose.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.Glucose.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['Glucose'].skew()
# Out:
# 0.5309885349396285

# %% [markdown]
# __As we can see this feature is almost normally distributed so it does not need transformation and we can directly jump to the outliers treatment.__
#
#
# # Outiers treatment

# %%
sns.boxplot(data.Glucose)      #No outliers in the glucose column
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Glucose'>

# %% [markdown]
# # Blood Pressure

# %%
data.BloodPressure.describe()
# Out:
# count    733.000000
# mean      72.405184
# std       12.382158
# min       24.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %%
data['BloodPressure'].isnull().sum()
# Out:
# 35

# %%
data.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness                 0
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# SkinThickness_sqrt            0
# SkinThickness_log             0
# dtype: int64

# %% [markdown]
# Now we have 35 null values in in total so we can replce them either with mean or median.

# %%
sns.distplot(data.BloodPressure)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BloodPressure', ylabel='Density'>

# %%
data['BloodPressure'].skew()
# Out:
# 0.13415273171959252

# %%
data['BloodPressure'].isna().sum()
# Out:
# 35

# %%
# Distribution of feature is normal so we can replace the null values with mean


data['BloodPressure'].fillna(data['BloodPressure'].mean(),inplace=True)

# %%
data['BloodPressure'].isna().sum()
# Out:
# 0

# %% [markdown]
# - Missing values filled.
#
# - Done with BloodPressure feature as well.

# %% [markdown]
# # BMI

# %%
sns.distplot(data.BMI)
plt.axvline(x = data.BMI.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.BMI.median(), color = 'blue', alpha = 0.8, label = 'Median')
plt.legend()
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['BMI'].skew()  #skewness is around 0.6 may need to be transformed.
# Out:
# 0.5939697505712673

# %%
data['BMI_log'] = np.log(data['BMI'])
sns.distplot(data.BMI_log)
plt.axvline(x = data.BMI_log.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.BMI_log.median(), color = 'blue', alpha = 0.8, label = 'Median')
plt.legend()
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['BMI_log'].skew()
# Out:
# -0.052153272939463785

# %% [markdown]
# - __Our data is normal now.__

# %%
data['BMI'].fillna(data.BMI.mean(), inplace = True)

# %% [markdown]
# # Outliers

# %%
sns.boxplot(data.BMI)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BMI'>

# %%
q1 = np.quantile(data['SkinThickness'], 0.25, interpolation = 'midpoint')
q3 = np.quantile(data['SkinThickness'], 0.75, interpolation = 'midpoint')
iqr = q3-q1
low = q1 - 1.5*iqr
up = q3 + 1.5*iqr

# %%
outliers = data[(data['BMI']>up)|(data['BMI']<low)]
outliers
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 4              0    137.0           40.0           35.0    168.0  43.1
# 16             0    118.0           84.0           47.0    230.0  45.8
# 18             1    103.0           30.0           38.0     83.0  43.3
# 43             9    171.0          110.0           24.0    240.0  45.4
# 57             0    100.0           88.0           53.0    110.0  46.8
# ..           ...      ...            ...            ...      ...   ...
# 732            2    174.0           88.0           37.0    120.0  44.5
# 746            1    147.0           94.0           41.0      NaN  49.3
# 747            1     81.0           74.0           41.0     57.0  46.3
# 753            0    181.0           88.0           44.0    510.0  43.3
# 761            9    170.0           74.0           31.0      NaN  44.0
#
#      DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt  \
# ...

# %% [markdown]
# #  Insulin

# %%
sns.distplot(data.Insulin)
plt.axvline(x = data.Insulin.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.Insulin.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['Insulin'].fillna(data.Insulin.median(), inplace = True)

# %%
sns.distplot(data.Insulin)
plt.axvline(x = data.Insulin.mean(), color = 'black', alpha = 0.8, label = 'Mean')
plt.axvline(x = data.Insulin.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(data.Insulin)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Insulin'>

# %% [markdown]
# __There are so many outliers in this feature so there is no point of keeping such feature that has so many outliers and
# Missing values in it so it will be better to remove it__.

# %%
data.drop(columns= 'Insulin', inplace = True)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0            6    148.0           72.0       35.00000  33.6
# 1            1     85.0           66.0       29.00000  26.6
# 2            8    183.0           64.0       29.15342  23.3
# 3            1     89.0           66.0       23.00000  28.1
# 4            0    137.0           40.0       35.00000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt  \
# 0                     0.627   50        1            5.916080
# 1                     0.351   31        0            5.385165
# 2                     0.672   32        1            5.399391
# 3                     0.167   21        0            4.795832
# 4                     2.288   33        1            5.916080
#
#    SkinThickness_log   BMI_log
# 0           3.555348  3.514526
# 1           3.367296  3.280911
# 2           3.372572  3.148453
# 3           3.135494  3.335770
# 4           3.555348  3.763523

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   763 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   BMI                       768 non-null    float64
#  5   DiabetesPedigreeFunction  768 non-null    float64
#  6   Age                       768 non-null    int64
#  7   Outcome                   768 non-null    int64
#  8   SkinThickness_sqrt        768 non-null    float64
#  9   SkinThickness_log         768 non-null    float64
#  10  BMI_log                   757 non-null    float64
# dtypes: float64(8), int64(3)
# memory usage: 66.1 KB

# %% [markdown]
# #  Pregnancies

# %%
sns.histplot(data.Pregnancies, kde = True)
plt.axvline(x = data.Pregnancies.mean(), color = 'black', alpha = 1, label = 'Mean')
plt.axvline(x = data.Pregnancies.median(), color = 'blue', alpha = 0.8, label = 'Median')

# %%
#The data is looking skewed so we should check it.....

data['Pregnancies'].skew()
# Out:
# 0.9016739791518588

# %%
data['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
data['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14],
#       dtype=int64)

# %% [markdown]
# - __There are some extreme values present in this feature so we need to treat the erronous values and outliers first.__

# %%
sns.boxplot(data.Pregnancies)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pregnancies'>

# %%
# First quartile (Q1)
Q1 = np.quantile(data["Pregnancies"], 0.25, interpolation = 'midpoint')
  
# Third quartile (Q3)
Q3 = np.quantile(data["Pregnancies"], 0.75, interpolation = 'midpoint')
  
# Interquaritle range (IQR)
IQR = Q3 - Q1

# %%
Q1
# Out:
# 1.0

# %%
Q3
# Out:
# 6.0

# %%
IQR
# Out:
# 5.0

# %%
lower = 0
upper = Q3 + 1.5*IQR
lower, upper
# Out:
# (0, 13.5)

# %%
data[(data["Pregnancies"]<lower)|(data["Pregnancies"]> upper)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 88            15    136.0           70.0           32.0  37.1
# 159           17    163.0           72.0           41.0  40.9
# 298           14    100.0           78.0           25.0  36.6
# 455           14    175.0           62.0           30.0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt  \
# 88                      0.153   43        1            5.656854
# 159                     0.817   47        1            6.403124
# 298                     0.412   46        1            5.000000
# 455                     0.212   38        1            5.477226
#
#      SkinThickness_log   BMI_log
# 88            3.465736  3.613617
# 159           3.713572  3.711130
# 298           3.218876  3.600048
# 455           3.401197  3.514526

# %%
cleaned_data = data[(data["Pregnancies"]>lower)&(data["Pregnancies"]< upper)]
cleaned_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              6    148.0           72.0       35.00000  33.6
# 1              1     85.0           66.0       29.00000  26.6
# 2              8    183.0           64.0       29.15342  23.3
# 3              1     89.0           66.0       23.00000  28.1
# 5              5    116.0           74.0       29.15342  25.6
# ..           ...      ...            ...            ...   ...
# 763           10    101.0           76.0       48.00000  32.9
# 764            2    122.0           70.0       27.00000  36.8
# 765            5    121.0           72.0       23.00000  26.2
# 766            1    126.0           60.0       29.15342  30.1
# 767            1     93.0           70.0       31.00000  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt  \
# 0                       0.627   50        1            5.916080
# 1                       0.351   31        0            5.385165
# ...

# %%
sns.boxplot(cleaned_data.Pregnancies)
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pregnancies'>

# %% [markdown]
# __Now since we have removed outliers we can Go with the normalization of this feature.__

# %%
cleaned_data['Pregnancies_sqrt'] = np.sqrt(cleaned_data['Pregnancies'])
sns.histplot(cleaned_data.Pregnancies_sqrt)
plt.axvline(x = cleaned_data.Pregnancies_sqrt.mean(), color = 'black', alpha = 1, label = 'Mean')
plt.axvline(x = cleaned_data.Pregnancies_sqrt.median(), color = 'blue', alpha = 0.8, label = 'Median')
# Out:
# <ipython-input-85-0fcfa0932949>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['Pregnancies_sqrt'] = np.sqrt(cleaned_data['Pregnancies'])

# %%
data['Pregnancies'].describe()
# Out:
# count    768.000000
# mean       3.845052
# std        3.369578
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        6.000000
# max       17.000000
# Name: Pregnancies, dtype: float64

# %%
cleaned_data['Pregnancies_sqrt'].skew()  #our feature is no more skewed it is normal now
# Out:
# 0.2804568932360121

# %%
cleaned_data['Pregnancies'].describe()
# Out:
# count    653.000000
# mean       4.430322
# std        3.118341
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        7.000000
# max       13.000000
# Name: Pregnancies, dtype: float64

# %% [markdown]
# 1). The dataset given is about the diagnosis of diabetis on the basis of given parameters in the form of columns.
#     One important thing to note is that this is the dataset about women only.....since we have number of times pregnent details
#     too.
# 2). There are 9 columns given out of which:
#     Categorical data : Outcome(nominal)
#     Numerical data:  1).Discrete: pregnancies
#                      2).Continuous data: age, BMI, insulin, skin thickness, Diabetes Pedigree Function, blood pressure
#
# 3). The overall shape of the data consists of 9 columns and 768 rows. So we have 768 observations or say data of 468 patients.
# 4). Talking about missing values there are no missing values in any of the column as we can see it using the function
#     isna().

# %% [markdown]
# # Before discussing the relation between age and glucose there  are few things which we need to know:
#  Based on the information given in dataset these glucose levels are collected based on the oral glucose tolerance test.
#  The following things are done:
# A Fasting blood glucose is measured as the first step of this test.
# For Oral Glucose test, 75 gm solution of glucose is fed orally. Blood samples are again taken at intervals of one hour and two hours after feeding the solution.
# For Gestational diabetes test, the above mentioned test is done along with the following test:
#
# After the sample is taken for fasting blood glucose, 50 gm glucose solution is fed and the blood sample is taken after one hour. If the test results are positive, further test is done.
# A 100 g glucose solution is fed and blood samples are taken at intervals of one, two and three hours.
#
# Results are measured as follows:
#
# Below 100 mg/dl is normal result for fasting blood glucose.
# 100 to 125 mg/dl of blood glucose is prediabetes.
# Higher than 126 mg/dl can be diabetes.
#
# Now, since we are aware about the normal levels and high levels too....so we are good to go.

# %% [markdown]
# # Conclusion:
#
#  We can conclude from the above plot that. Most of the normal glucose level isfound in the age groups of
#  20 to 30 years. So we can say that people lying in these age groups have normal glucose level.
#  On the other hand, as the age is increasing we can see most of the data points are lying above 100.
#  which is a sign of being prediabetic that means there is a risk of diabetes within these age groups.(above 30).
#  One interesting thing that we can observe here is that though the glucose level of almost all aged people is above  100
#  but it is not like this is not the case with younger peope of 20-30 age group.
#  We can see that higher glucose levels are present here too but yeah...people with normal levels are also kind of balancing it.

# %%
cleaned_data.skew()
# Out:
# Pregnancies                 0.795442
# Glucose                     0.541183
# BloodPressure               0.125662
# SkinThickness               0.076367
# BMI                         0.465853
# DiabetesPedigreeFunction    1.638243
# Age                         1.026768
# Outcome                     0.648526
# SkinThickness_sqrt         -0.210400
# SkinThickness_log          -1.092221
# BMI_log                    -0.096069
# Pregnancies_sqrt            0.280457
# pedigree_log                0.072197
# dtype: float64

# %% [markdown]
# This overview is telling us that none of our data column has normally distributed values.
# Skewness can be seen everywhere but the extent of skewness is marginal...with Insulin having highest skewness
# of 2.272251 which means the peak will be 2.2..way from the mean.(most values will lie here).
#
# Now, it's time to visualize it all through graph.....so here we go...

# %% [markdown]
# # Age

# %%
sns.distplot(cleaned_data.Age)
plt.axvline(x = cleaned_data.Age.mean(), color = 'red', alpha = 0.6, label = 'Mean')
plt.axvline(x = cleaned_data.Age.median(), color = 'blue', ls = '--', label = 'Median')
plt.legend()
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cleaned_data['Age'].skew()
# Out:
# 1.0267684115926847

# %%
cleaned_data['Age_log'] = np.log(cleaned_data['Age'])
sns.distplot(cleaned_data.Age)
plt.axvline(x = cleaned_data.Age.mean(), color = 'red', alpha = 0.6, label = 'Mean')
plt.axvline(x = cleaned_data.Age.median(), color = 'blue', ls = '--', label = 'Median')
plt.legend()
# Out:
# <ipython-input-140-1e72b2c2623e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['Age_log'] = np.log(cleaned_data['Age'])
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cleaned_data['Age_log'].skew()    #This feature is almost normal
# Out:
# 0.49012034127691984

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'Pregnancies', data = data)
# Out:
# <AxesSubplot:xlabel='Pregnancies', ylabel='count'>

# %% [markdown]
# # Diabetes Pedigree Function

# %%
sns.boxplot(x= "DiabetesPedigreeFunction", data = data)
# Out:
# <AxesSubplot:xlabel='DiabetesPedigreeFunction'>

# %%
sns.distplot(cleaned_data.DiabetesPedigreeFunction, kde = True)
plt.axvline(x = cleaned_data.DiabetesPedigreeFunction.mean(), color = 'red', alpha = 0.5, label = 'Mean')
plt.axvline(x = cleaned_data.DiabetesPedigreeFunction.median(), color = 'blue', ls = '--',label = 'Median')
plt.legend()
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cleaned_data['DiabetesPedigreeFunction'].skew()  #Feature is highly skewed
# Out:
# 1.638243171832594

# %%
cleaned_data['pedigree_log'] = np.log(cleaned_data['DiabetesPedigreeFunction'])
sns.distplot(cleaned_data.pedigree_log, kde = True)
plt.axvline(x = cleaned_data.pedigree_log.mean(), color = 'red', alpha = 0.5, label = 'Mean')
plt.axvline(x = cleaned_data.pedigree_log.median(), color = 'blue', ls = '--',label = 'Median')
plt.legend()
# Out:
# <ipython-input-121-ee26fab3d717>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['pedigree_log'] = np.log(cleaned_data['DiabetesPedigreeFunction'])
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
cleaned_data['pedigree_log'].skew()   #Skewness removed
# Out:
# 0.07219707450550658

# %% [markdown]
# __- Null Values check__

# %%
cleaned_data['pedigree_log'].isna().sum()  #No null values
# Out:
# 0

# %% [markdown]
# __- Outliers__

# %%
sns.boxplot(cleaned_data.pedigree_log)   #No Outliers deducted
# Out:
# C:\Users\Bakul anmol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pedigree_log'>

# %% [markdown]
# # All the features are now normal, cleaned and free from outliers.
#
# - __Here I have kept the unengineered features also__.

# %% [markdown]
# # Bivariate Analysis
#
#
# - __Relation between different features.__
#
# - __Before that we will take a look at our dataset once again.__

# %%
cleaned_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0            6    148.0           72.0       35.00000  33.6
# 1            1     85.0           66.0       29.00000  26.6
# 2            8    183.0           64.0       29.15342  23.3
# 3            1     89.0           66.0       23.00000  28.1
# 5            5    116.0           74.0       29.15342  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome  SkinThickness_sqrt  \
# 0                     0.627   50        1            5.916080
# 1                     0.351   31        0            5.385165
# 2                     0.672   32        1            5.399391
# 3                     0.167   21        0            4.795832
# 5                     0.201   30        0            5.399391
#
#    SkinThickness_log   BMI_log  Pregnancies_sqrt  pedigree_log   Age_log  \
# 0           3.555348  3.514526          2.449490     -0.466809  3.912023
# 1           3.367296  3.280911          1.000000     -1.046969  3.433987
# ...

# %%
plt.figure(figsize= (10,15))
corr = cleaned_data.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
sns.scatterplot(x = 'Age_log', y = 'Pregnancies_sqrt', hue = 'Outcome',data = cleaned_data)
# Out:
# <AxesSubplot:xlabel='Age_log', ylabel='Pregnancies_sqrt'>

# %%
sns.regplot(x = 'Age_log', y = 'Pregnancies_sqrt',data = cleaned_data)
# Out:
# <AxesSubplot:xlabel='Age_log', ylabel='Pregnancies_sqrt'>

# %%
sns.boxplot(y = 'BMI', x = 'Outcome',data = cleaned_data)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='BMI'>

# %% [markdown]
# - From the pllot above its clear that the people having higher BMI Are more diabetic so there is a positive relation
#   between  these two factors.
#
#
#
# - Zero outcome one is lying between 20-49 . However if we look at the outcome one then its range falls between 25- 55
#   so people with higher BMI are at risk of getting diabetic.
